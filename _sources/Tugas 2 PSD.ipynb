# %% [markdown]
# # **TUGAS 2 PSD C**

# %%
# !pip install psycopg2-binary
# !pip install mysql-connector-python
# !pip install pymysql
# !pip install pyodbc
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 34.7 MB/s eta 0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-8.0.32-cp39-cp39-manylinux1_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 45.4 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<=3.20.3,>=3.11.0 in /usr/local/lib/python3.9/dist-packages (from mysql-connector-python) (3.19.6)
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-8.0.32
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 KB 2.1 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyodbc
#   Downloading pyodbc-4.0.35-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (329 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.8/329.8 KB 7.5 MB/s eta 0:00:00
# Installing collected packages: pyodbc
# Successfully installed pyodbc-4.0.35
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)

# %% [markdown]
# ## Get Data Sepal-Length from Posgresql Elephant

# %% [markdown]
# *   koneksikan database postgresql menggunakan library psycopg2
# *   Setelah itu, sebuah cursor (penunjuk posisi pada database) dibuat untuk menjalankan query SQL.
# *   Hasil query disimpan pada variabel hasil_query, kemudian dimasukkan ke dalam DataFrame dengan nama kolom yang diinginkan, yaitu "id" dan "sepallength"
# *   Setelah selesai, cursor dan koneksi ditutup menggunakan fungsi close().

# %%
import psycopg2
import pandas as pd

# Buat koneksi ke PostgreSQL.
conn = psycopg2.connect(database="jflcgkqa", user="jflcgkqa", password="tkUR1gKave5-xZWDJuUrIXtfZTH-fxdo", host="floppy.db.elephantsql.com", port="5432")


# Buat cursor untuk menjalankan query SQL.
cur = conn.cursor()

# Jalankan query SQL.
cur.execute("SELECT ROW_NUMBER() OVER () as id, sepallength FROM iris;")

# Ambil hasil query.
hasil_query = cur.fetchall()

df_sepallength = pd.DataFrame(hasil_query, columns=["id", "sepallength"])

print(df_sepallength)

# Tutup cursor dan koneksi.
cur.close()
conn.close()
# Out:
#       id sepallength
# 0      1         5.1
# 1      2         4.9
# 2      3         4.7
# 3      4         4.6
# 4      5           5
# ..   ...         ...
# 145  146         6.7
# 146  147         6.3
# 147  148         6.5
# 148  149         6.2
# 149  150         5.9
#
# [150 rows x 2 columns]

# %% [markdown]
# ## Get Data Petal-Width + Class from iris.csv

# %% [markdown]
# *   baca file iris.csv, ambil kolom petalwidth dan kolom class
# *   insert kolom id kedepan tabel, yang berisikan value dari 1 sampai panjang data.

# %%
import pandas as pd

# membaca file CSV dan memilih kolom tertentu
df_petalwidth = pd.read_csv('iris.arff.csv', usecols=['petalwidth', 'class'])

#insert id ke depan
df_petalwidth.insert(0, 'id', range(1, len(df_petalwidth) + 1))
print(df_petalwidth)
# Out:
#       id  petalwidth           class
# 0      1         0.2     Iris-setosa
# 1      2         0.2     Iris-setosa
# 2      3         0.2     Iris-setosa
# 3      4         0.2     Iris-setosa
# 4      5         0.2     Iris-setosa
# ..   ...         ...             ...
# 145  146         2.3  Iris-virginica
# 146  147         1.9  Iris-virginica
# 147  148         2.0  Iris-virginica
# 148  149         2.3  Iris-virginica
# 149  150         1.8  Iris-virginica
#
# [150 rows x 3 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Get Data Sepal-Width from Posgresql Elephant

# %% [markdown]
# *   koneksikan database postgresql menggunakan library psycopg2
# *   Setelah itu, sebuah cursor (penunjuk posisi pada database) dibuat untuk menjalankan query SQL.
# *   Hasil query disimpan pada variabel hasil_query, kemudian dimasukkan ke dalam DataFrame dengan nama kolom yang diinginkan, yaitu "id" dan "sepalwidth"
# *   Setelah selesai, cursor dan koneksi ditutup menggunakan fungsi close().

# %%
import psycopg2
import pandas as pd

# Buat koneksi ke PostgreSQL.
conn = psycopg2.connect(database="jflcgkqa", user="jflcgkqa", password="tkUR1gKave5-xZWDJuUrIXtfZTH-fxdo", host="floppy.db.elephantsql.com", port="5432")


# Buat cursor untuk menjalankan query SQL.
cur = conn.cursor()

# Jalankan query SQL.
cur.execute("SELECT ROW_NUMBER() OVER () as id, sepalwidth FROM iris;")

# Ambil hasil query.
hasil_query = cur.fetchall()

df_sepalwidth = pd.DataFrame(hasil_query, columns=["id", "sepalwidth"])

print(df_sepalwidth)

# Tutup cursor dan koneksi.
cur.close()
conn.close()
# Out:
#       id sepalwidth
# 0      1        3.5
# 1      2          3
# 2      3        3.2
# 3      4        3.1
# 4      5        3.6
# ..   ...        ...
# 145  146          3
# 146  147        2.5
# 147  148          3
# 148  149        3.4
# 149  150          3
#
# [150 rows x 2 columns]

# %% [markdown]
# ## Get Data Petal-Length from Mysql

# %% [markdown]
# *   koneksikan database mysql local menggunakan library mysql.connector
# *   Setelah itu, sebuah cursor (penunjuk posisi pada database) dibuat untuk menjalankan query SQL.
# *   Hasil query disimpan pada variabel hasil_query, kemudian dimasukkan ke dalam DataFrame dengan nama kolom yang diinginkan, yaitu "id" dan "petallength"
# *   Setelah selesai, cursor dan koneksi ditutup menggunakan fungsi close().

# %%
import mysql.connector as mc
import pandas as pd

conn = mc.connect(db="petal_length", user="admin",passwd="ZDFHM60q",host="mysql-114539-0.cloudclusters.net", port=10002,autocommit=True)

# Buat cursor untuk menjalankan query SQL.
cur = conn.cursor()

# Jalankan query SQL.
cur.execute("SELECT * From iris")

# Ambil hasil query.
hasil_query = cur.fetchall()

df_petallength = pd.DataFrame(hasil_query, columns=["id", "petallength"])

print(df_petallength)

# Tutup cursor dan koneksi.
cur.close()
conn.close()
# Out:
#       id petallength
# 0      1         1.4
# 1      2         1.4
# 2      3         1.3
# 3      4         1.5
# 4      5         1.4
# ..   ...         ...
# 145  146         5.2
# 146  147         5.0
# 147  148         5.2
# 148  149         5.4
# 149  150         5.1
#
# [150 rows x 2 columns]

# %% [markdown]
# melakukan penggabungan empat kolom data yang ada dalam beberapa kerangka data (dataframe) menjadi satu dataframe tunggal.

# %%
result = pd.concat([df_petallength, df_sepallength, df_sepalwidth, df_petalwidth], axis=1)
result
# Out:
#       id petallength   id sepallength   id sepalwidth   id  petalwidth  \
# 0      1         1.4    1         5.1    1        3.5    1         0.2
# 1      2         1.4    2         4.9    2          3    2         0.2
# 2      3         1.3    3         4.7    3        3.2    3         0.2
# 3      4         1.5    4         4.6    4        3.1    4         0.2
# 4      5         1.4    5           5    5        3.6    5         0.2
# ..   ...         ...  ...         ...  ...        ...  ...         ...
# 145  146         5.2  146         6.7  146          3  146         2.3
# 146  147         5.0  147         6.3  147        2.5  147         1.9
# 147  148         5.2  148         6.5  148          3  148         2.0
# 148  149         5.4  149         6.2  149        3.4  149         2.3
# 149  150         5.1  150         5.9  150          3  150         1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 9 columns]

# %% [markdown]
# *   menghapus kolom id
# *   menyisakan kolom yang di perlukan

# %%
result.drop(result.columns[[0,2,4,6]],axis=1,inplace=True)
result
# Out:
#     petallength sepallength sepalwidth  petalwidth           class
# 0           1.4         5.1        3.5         0.2     Iris-setosa
# 1           1.4         4.9          3         0.2     Iris-setosa
# 2           1.3         4.7        3.2         0.2     Iris-setosa
# 3           1.5         4.6        3.1         0.2     Iris-setosa
# 4           1.4           5        3.6         0.2     Iris-setosa
# ..          ...         ...        ...         ...             ...
# 145         5.2         6.7          3         2.3  Iris-virginica
# 146         5.0         6.3        2.5         1.9  Iris-virginica
# 147         5.2         6.5          3         2.0  Iris-virginica
# 148         5.4         6.2        3.4         2.3  Iris-virginica
# 149         5.1         5.9          3         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
X = result.values[:, :4]
Y = result.values[:, 4]
print(X)
# Out:
# [[Decimal('1.4') '5.1' '3.5' 0.2]
#  [Decimal('1.4') '4.9' '3' 0.2]
#  [Decimal('1.3') '4.7' '3.2' 0.2]
#  [Decimal('1.5') '4.6' '3.1' 0.2]
#  [Decimal('1.4') '5' '3.6' 0.2]
#  [Decimal('1.7') '5.4' '3.9' 0.4]
#  [Decimal('1.4') '4.6' '3.4' 0.3]
#  [Decimal('1.5') '5' '3.4' 0.2]
#  [Decimal('1.4') '4.4' '2.9' 0.2]
#  [Decimal('1.5') '4.9' '3.1' 0.1]
#  [Decimal('1.5') '5.4' '3.7' 0.2]
#  [Decimal('1.6') '4.8' '3.4' 0.2]
#  [Decimal('1.4') '4.8' '3' 0.1]
#  [Decimal('1.1') '4.3' '3' 0.1]
#  [Decimal('1.2') '5.8' '4' 0.2]
#  [Decimal('1.5') '5.7' '4.4' 0.4]
#  [Decimal('1.3') '5.4' '3.9' 0.4]
#  [Decimal('1.4') '5.1' '3.5' 0.3]
#  [Decimal('1.7') '5.7' '3.8' 0.3]
#  [Decimal('1.5') '5.1' '3.8' 0.3]
#  [Decimal('1.7') '5.4' '3.4' 0.2]
#  [Decimal('1.5') '5.1' '3.7' 0.4]
#  [Decimal('1.0') '4.6' '3.6' 0.2]
#  [Decimal('1.7') '5.1' '3.3' 0.5]
#  [Decimal('1.9') '4.8' '3.4' 0.2]
#  [Decimal('1.6') '5' '3' 0.2]
#  [Decimal('1.6') '5' '3.4' 0.4]
#  [Decimal('1.5') '5.2' '3.5' 0.2]
#  [Decimal('1.4') '5.2' '3.4' 0.2]
#  [Decimal('1.6') '4.7' '3.2' 0.2]
#  [Decimal('1.6') '4.8' '3.1' 0.2]
#  [Decimal('1.5') '5.4' '3.4' 0.4]
#  [Decimal('1.5') '5.2' '4.1' 0.1]
#  [Decimal('1.4') '5.5' '4.2' 0.2]
#  [Decimal('1.5') '4.9' '3.1' 0.1]
#  [Decimal('1.2') '5' '3.2' 0.2]
#  [Decimal('1.3') '5.5' '3.5' 0.2]
#  [Decimal('1.5') '4.9' '3.1' 0.1]
#  [Decimal('1.3') '4.4' '3' 0.2]
#  [Decimal('1.5') '5.1' '3.4' 0.2]
#  [Decimal('1.3') '5' '3.5' 0.3]
#  [Decimal('1.3') '4.5' '2.3' 0.3]
#  [Decimal('1.3') '4.4' '3.2' 0.2]
#  [Decimal('1.6') '5' '3.5' 0.6]
#  [Decimal('1.9') '5.1' '3.8' 0.4]
#  [Decimal('1.4') '4.8' '3' 0.3]
#  [Decimal('1.6') '5.1' '3.8' 0.2]
#  [Decimal('1.4') '4.6' '3.2' 0.2]
#  [Decimal('1.5') '5.3' '3.7' 0.2]
#  [Decimal('1.4') '5' '3.3' 0.2]
#  [Decimal('4.7') '7' '3.2' 1.4]
#  [Decimal('4.5') '6.4' '3.2' 1.5]
#  [Decimal('4.9') '6.9' '3.1' 1.5]
#  [Decimal('4.0') '5.5' '2.3' 1.3]
#  [Decimal('4.6') '6.5' '2.8' 1.5]
#  [Decimal('4.5') '5.7' '2.8' 1.3]
#  [Decimal('4.7') '6.3' '3.3' 1.6]
#  [Decimal('3.3') '4.9' '2.4' 1.0]
#  [Decimal('4.6') '6.6' '2.9' 1.3]
#  [Decimal('3.9') '5.2' '2.7' 1.4]
#  [Decimal('3.5') '5' '2' 1.0]
#  [Decimal('4.2') '5.9' '3' 1.5]
#  [Decimal('4.0') '6' '2.2' 1.0]
#  [Decimal('4.7') '6.1' '2.9' 1.4]
#  [Decimal('3.6') '5.6' '2.9' 1.3]
#  [Decimal('4.4') '6.7' '3.1' 1.4]
#  [Decimal('4.5') '5.6' '3' 1.5]
#  [Decimal('4.1') '5.8' '2.7' 1.0]
#  [Decimal('4.5') '6.2' '2.2' 1.5]
#  [Decimal('3.9') '5.6' '2.5' 1.1]
#  [Decimal('4.8') '5.9' '3.2' 1.8]
#  [Decimal('4.0') '6.1' '2.8' 1.3]
#  [Decimal('4.9') '6.3' '2.5' 1.5]
#  [Decimal('4.7') '6.1' '2.8' 1.2]
#  [Decimal('4.3') '6.4' '2.9' 1.3]
#  [Decimal('4.4') '6.6' '3' 1.4]
#  [Decimal('4.8') '6.8' '2.8' 1.4]
#  [Decimal('5.0') '6.7' '3' 1.7]
#  [Decimal('4.5') '6' '2.9' 1.5]
#  [Decimal('3.5') '5.7' '2.6' 1.0]
#  [Decimal('3.8') '5.5' '2.4' 1.1]
#  [Decimal('3.7') '5.5' '2.4' 1.0]
#  [Decimal('3.9') '5.8' '2.7' 1.2]
#  [Decimal('5.1') '6' '2.7' 1.6]
#  [Decimal('4.5') '5.4' '3' 1.5]
#  [Decimal('4.5') '6' '3.4' 1.6]
#  [Decimal('4.7') '6.7' '3.1' 1.5]
#  [Decimal('4.4') '6.3' '2.3' 1.3]
#  [Decimal('4.1') '5.6' '3' 1.3]
#  [Decimal('4.0') '5.5' '2.5' 1.3]
#  [Decimal('4.4') '5.5' '2.6' 1.2]
#  [Decimal('4.6') '6.1' '3' 1.4]
#  [Decimal('4.0') '5.8' '2.6' 1.2]
#  [Decimal('3.3') '5' '2.3' 1.0]
#  [Decimal('4.2') '5.6' '2.7' 1.3]
#  [Decimal('4.2') '5.7' '3' 1.2]
#  [Decimal('4.2') '5.7' '2.9' 1.3]
#  [Decimal('4.3') '6.2' '2.9' 1.3]
#  [Decimal('3.0') '5.1' '2.5' 1.1]
#  [Decimal('4.1') '5.7' '2.8' 1.3]
#  [Decimal('6.0') '6.3' '3.3' 2.5]
#  [Decimal('5.1') '5.8' '2.7' 1.9]
#  [Decimal('5.9') '7.1' '3' 2.1]
#  [Decimal('5.6') '6.3' '2.9' 1.8]
#  [Decimal('5.8') '6.5' '3' 2.2]
#  [Decimal('6.6') '7.6' '3' 2.1]
#  [Decimal('4.5') '4.9' '2.5' 1.7]
#  [Decimal('6.3') '7.3' '2.9' 1.8]
#  [Decimal('5.8') '6.7' '2.5' 1.8]
#  [Decimal('6.1') '7.2' '3.6' 2.5]
#  [Decimal('5.1') '6.5' '3.2' 2.0]
#  [Decimal('5.3') '6.4' '2.7' 1.9]
#  [Decimal('5.5') '6.8' '3' 2.1]
#  [Decimal('5.0') '5.7' '2.5' 2.0]
#  [Decimal('5.1') '5.8' '2.8' 2.4]
#  [Decimal('5.3') '6.4' '3.2' 2.3]
#  [Decimal('5.5') '6.5' '3' 1.8]
#  [Decimal('6.7') '7.7' '3.8' 2.2]
#  [Decimal('6.9') '7.7' '2.6' 2.3]
#  [Decimal('5.0') '6' '2.2' 1.5]
#  [Decimal('5.7') '6.9' '3.2' 2.3]
#  [Decimal('4.9') '5.6' '2.8' 2.0]
#  [Decimal('6.7') '7.7' '2.8' 2.0]
#  [Decimal('4.9') '6.3' '2.7' 1.8]
#  [Decimal('5.7') '6.7' '3.3' 2.1]
#  [Decimal('6.0') '7.2' '3.2' 1.8]
#  [Decimal('4.8') '6.2' '2.8' 1.8]
#  [Decimal('4.9') '6.1' '3' 1.8]
#  [Decimal('5.6') '6.4' '2.8' 2.1]
#  [Decimal('5.8') '7.2' '3' 1.6]
#  [Decimal('6.1') '7.4' '2.8' 1.9]
#  [Decimal('6.4') '7.9' '3.8' 2.0]
#  [Decimal('5.6') '6.4' '2.8' 2.2]
#  [Decimal('5.1') '6.3' '2.8' 1.5]
#  [Decimal('5.6') '6.1' '2.6' 1.4]
#  [Decimal('6.1') '7.7' '3' 2.3]
#  [Decimal('5.6') '6.3' '3.4' 2.4]
#  [Decimal('5.5') '6.4' '3.1' 1.8]
#  [Decimal('4.8') '6' '3' 1.8]
#  [Decimal('5.4') '6.9' '3.1' 2.1]
#  [Decimal('5.6') '6.7' '3.1' 2.4]
#  [Decimal('5.1') '6.9' '3.1' 2.3]
#  [Decimal('5.1') '5.8' '2.7' 1.9]
#  [Decimal('5.9') '6.8' '3.2' 2.3]
#  [Decimal('5.7') '6.7' '3.3' 2.5]
#  [Decimal('5.2') '6.7' '3' 2.3]
#  [Decimal('5.0') '6.3' '2.5' 1.9]
#  [Decimal('5.2') '6.5' '3' 2.0]
#  [Decimal('5.4') '6.2' '3.4' 2.3]
#  [Decimal('5.1') '5.9' '3' 1.8]]

# %% [markdown]
# untuk membagi dataset menjadi data training dan data testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( 
    X, Y, test_size = 0.2, random_state = 100)

# %% [markdown]
#  implementasi dari algoritma Decision Tree untuk klasifikasi menggunakan Python dan library Scikit-learn (sklearn).

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# Menampilkan akurasi dari metode decision tree

# %%
from sklearn.metrics import accuracy_score
print (" DecisionTree Accuracy : ",
    accuracy_score(y_test,y_pred)*100)
# Out:
#  DecisionTree Accuracy :  96.66666666666667

# %% [markdown]
# implementasi dari KNN classifier untuk klasifikasi menggunakan Python dan library Scikit-learn (sklearn).

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# Menampilkan akurasi dari metode KNN Classifier

# %%
print (" KNN Accuracy : ",
    accuracy_score(y_test,y_pred)*100)
# Out:
#  KNN Accuracy :  100.0
